# %%
import ray
import os
from ray import tune, air
from ray.rllib.algorithms import dqn, ppo, sac

import optparse

# from sumo_env import sumoEnv
# from train_env import sumoEnv
from single_lorry import sumoEnv

# %%
stop = {"training_iteration": 10}
rllib_config = {"env":sumoEnv,
            "env_config":{"algo":"transformer-repair-3days_maintain-4hours","repair":3,"maintain":4},
            "framework":"tf2",
            "num_workers":6,
            "ignore_worker_failures":True,
            "recreate_failed_workers":True,
            "disable_env_checking": True,
            "model": {
                "use_attention": True,
                "max_seq_len": 20,
                "attention_num_transformer_units": 1,
                "attention_dim": 32,
                "attention_memory_inference": 20,
                "attention_memory_training": 20,
                "attention_num_heads": 6,
                "attention_head_dim": 32,
                "attention_position_wise_mlp_dim": 32,
            },
}

ray_dir="/home/lwh/ray_transformer"

tunner = tune.Tuner(
    ppo.PPO,
    param_space=rllib_config,
    run_config=air.RunConfig(
        local_dir=ray_dir,
        stop=stop,
        checkpoint_config=air.CheckpointConfig(
            checkpoint_frequency=1,
            checkpoint_at_end=True,
        ),
    )
)

# %%
ray.init()
# Out:
# 2022-12-06 10:43:00,660	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.10', ray_version='2.1.0', ray_commit='be49bde7ee4f6adb3f8710aee0665c27f9f0bb62', address_info={'node_ip_address': '172.16.188.140', 'raylet_ip_address': '172.16.188.140', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-12-06_10-42-58_253923_604400/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-12-06_10-42-58_253923_604400/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/tmp/ray/session_2022-12-06_10-42-58_253923_604400', 'metrics_export_port': 52534, 'gcs_address': '172.16.188.140:63844', 'address': '172.16.188.140:63844', 'dashboard_agent_listen_port': 52365, 'node_id': 'e893b3e5ecf91fa0ade23c85fc8dc3bebec5b2d6e95b2500d8af1a76'})

# %%
result = tunner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2022-12-06 10:41:14</td></tr>
# <tr><td>Running for: </td><td>00:08:50.70        </td></tr>
# <tr><td>Memory:      </td><td>12.3/15.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 5.0/8 CPUs, 0/1 GPUs, 0.0/4.12 GiB heap, 0.0/2.06 GiB objects (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name             </th><th>status  </th><th>loc                  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_sumoEnv_37907_00000</td><td>RUNNING </td><td>172.16.188.140:583802</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (PPO pid=583802) 2022-12-06 10:32:29,329	INFO algorithm.py:2292 -- Executing eagerly (framework='tf2'), with eager_tracing=False. For production workloads, make sure to set eager_tracing=True  in order to match the speed of tf-static-graph (framework='tf'). For debugging purposes, `eager_tracing=False` is the best choice.
# (PPO pid=583802) 2022-12-06 10:32:29,331	INFO algorithm.py:457 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (RolloutWorker pid=583837) Model: "model_1"
# (RolloutWorker pid=583837) __________________________________________________________________________________________________
# (RolloutWorker pid=583837)  Layer (type)                   Output Shape         Param #     Connected to
# (RolloutWorker pid=583837) ==================================================================================================
# (RolloutWorker pid=583837)  inputs (InputLayer)            [(None, None, 256)]  0           []
# (RolloutWorker pid=583837)
# (RolloutWorker pid=583837)  dense (Dense)                  (None, None, 32)     8224        ['inputs[0][0]']
# (RolloutWorker pid=583837)
# (RolloutWorker pid=583837)  memory_in_0 (InputLayer)       [(None, None, 32)]   0           []
# (RolloutWorker pid=583837)
# (RolloutWorker pid=583837)  mha_1 (SkipConnection)         (None, None, 32)     37344       ['dense[0][0]',
# (RolloutWorker pid=583837)                                                                   'memory_in_0[0][0]']
# (RolloutWorker pid=583837)
# (RolloutWorker pid=583837)  pos_wise_mlp_1 (SkipConnection  (None, None, 32)    8352        ['mha_1[0][0]']
# (RolloutWorker pid=583837)  )
# (RolloutWorker pid=583837)
# (RolloutWorker pid=583837) ==================================================================================================
# (RolloutWorker pid=583837) Total params: 53,920
# (RolloutWorker pid=583837) Trainable params: 53,920
# (RolloutWorker pid=583837) Non-trainable params: 0
# (RolloutWorker pid=583837) __________________________________________________________________________________________________
# (RolloutWorker pid=583835) Model: "model_1"
# (RolloutWorker pid=583835) __________________________________________________________________________________________________
# (RolloutWorker pid=583835)  Layer (type)                   Output Shape         Param #     Connected to
# (RolloutWorker pid=583835) ==================================================================================================
# (RolloutWorker pid=583835)  inputs (InputLayer)            [(None, None, 256)]  0           []
# (RolloutWorker pid=583835)
# (RolloutWorker pid=583835)  dense (Dense)                  (None, None, 32)     8224        ['inputs[0][0]']
# (RolloutWorker pid=583835)
# (RolloutWorker pid=583835)  memory_in_0 (InputLayer)       [(None, None, 32)]   0           []
# (RolloutWorker pid=583835)
# (RolloutWorker pid=583835)  mha_1 (SkipConnection)         (None, None, 32)     37344       ['dense[0][0]',
# (RolloutWorker pid=583835)                                                                   'memory_in_0[0][0]']
# (RolloutWorker pid=583835)
# (RolloutWorker pid=583835)  pos_wise_mlp_1 (SkipConnection  (None, None, 32)    8352        ['mha_1[0][0]']
# (RolloutWorker pid=583835)  )
# (RolloutWorker pid=583835)
# (RolloutWorker pid=583835) ==================================================================================================
# (RolloutWorker pid=583835) Total params: 53,920
# (RolloutWorker pid=583835) Trainable params: 53,920
# (RolloutWorker pid=583835) Non-trainable params: 0
# (RolloutWorker pid=583835) __________________________________________________________________________________________________
# (RolloutWorker pid=583836) Model: "model_1"
# (RolloutWorker pid=583836) __________________________________________________________________________________________________
# (RolloutWorker pid=583836)  Layer (type)                   Output Shape         Param #     Connected to
# (RolloutWorker pid=583836) ==================================================================================================
# (RolloutWorker pid=583836)  inputs (InputLayer)            [(None, None, 256)]  0           []
# (RolloutWorker pid=583836)
# (RolloutWorker pid=583836)  dense (Dense)                  (None, None, 32)     8224        ['inputs[0][0]']
# (RolloutWorker pid=583836)
# (RolloutWorker pid=583836)  memory_in_0 (InputLayer)       [(None, None, 32)]   0           []
# (RolloutWorker pid=583836)
# (RolloutWorker pid=583836)  mha_1 (SkipConnection)         (None, None, 32)     37344       ['dense[0][0]',
# (RolloutWorker pid=583836)                                                                   'memory_in_0[0][0]']
# (RolloutWorker pid=583836)
# (RolloutWorker pid=583836)  pos_wise_mlp_1 (SkipConnection  (None, None, 32)    8352        ['mha_1[0][0]']
# (RolloutWorker pid=583836)  )
# (RolloutWorker pid=583836)
# (RolloutWorker pid=583836) ==================================================================================================
# (RolloutWorker pid=583836) Total params: 53,920
# (RolloutWorker pid=583836) Trainable params: 53,920
# (RolloutWorker pid=583836) Non-trainable params: 0
# (RolloutWorker pid=583836) __________________________________________________________________________________________________
# (RolloutWorker pid=583834) Model: "model_1"
# (RolloutWorker pid=583834) __________________________________________________________________________________________________
# (RolloutWorker pid=583834)  Layer (type)                   Output Shape         Param #     Connected to
# (RolloutWorker pid=583834) ==================================================================================================
# (RolloutWorker pid=583834)  inputs (InputLayer)            [(None, None, 256)]  0           []
# (RolloutWorker pid=583834)
# (RolloutWorker pid=583834)  dense (Dense)                  (None, None, 32)     8224        ['inputs[0][0]']
# (RolloutWorker pid=583834)
# (RolloutWorker pid=583834)  memory_in_0 (InputLayer)       [(None, None, 32)]   0           []
# (RolloutWorker pid=583834)
# (RolloutWorker pid=583834)  mha_1 (SkipConnection)         (None, None, 32)     37344       ['dense[0][0]',
# (RolloutWorker pid=583834)                                                                   'memory_in_0[0][0]']
# (RolloutWorker pid=583834)
# (RolloutWorker pid=583834)  pos_wise_mlp_1 (SkipConnection  (None, None, 32)    8352        ['mha_1[0][0]']
# (RolloutWorker pid=583834)  )
# (RolloutWorker pid=583834)
# (RolloutWorker pid=583834) ==================================================================================================
# (RolloutWorker pid=583834) Total params: 53,920
# (RolloutWorker pid=583834) Trainable params: 53,920
# (RolloutWorker pid=583834) Non-trainable params: 0
# (RolloutWorker pid=583834) __________________________________________________________________________________________________
# (PPO pid=583802) Model: "model_1"
# (PPO pid=583802) __________________________________________________________________________________________________
# (PPO pid=583802)  Layer (type)                   Output Shape         Param #     Connected to
# (PPO pid=583802) ==================================================================================================
# (PPO pid=583802)  inputs (InputLayer)            [(None, None, 256)]  0           []
# (PPO pid=583802)
# (PPO pid=583802)  dense (Dense)                  (None, None, 32)     8224        ['inputs[0][0]']
# (PPO pid=583802)
# (PPO pid=583802)  memory_in_0 (InputLayer)       [(None, None, 32)]   0           []
# (PPO pid=583802)
# (PPO pid=583802)  mha_1 (SkipConnection)         (None, None, 32)     37344       ['dense[0][0]',
# (PPO pid=583802)                                                                   'memory_in_0[0][0]']
# (PPO pid=583802)
# (PPO pid=583802)  pos_wise_mlp_1 (SkipConnection  (None, None, 32)    8352        ['mha_1[0][0]']
# (PPO pid=583802)  )
# (PPO pid=583802)
# (PPO pid=583802) ==================================================================================================
# (PPO pid=583802) Total params: 53,920
# (PPO pid=583802) Trainable params: 53,920
# (PPO pid=583802) Non-trainable params: 0
# (PPO pid=583802) __________________________________________________________________________________________________
# (PPO pid=583802) 2022-12-06 10:32:39,108	WARNING util.py:66 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=583837) episode:0
# (RolloutWorker pid=583837) using 8 cpus
# (RolloutWorker pid=583836) episode:0
# (RolloutWorker pid=583836) using 8 cpus
# (RolloutWorker pid=583834) episode:0
# (RolloutWorker pid=583834) using 8 cpus
# (RolloutWorker pid=583837)  Retrying in 1 seconds
# (RolloutWorker pid=583835) episode:0
# (RolloutWorker pid=583835) using 8 cpus
# (RolloutWorker pid=583835)  Retrying in 1 seconds
# (RolloutWorker pid=583836)  Retrying in 1 seconds
# (RolloutWorker pid=583834)  Retrying in 1 seconds
# (RolloutWorker pid=583837) Warning: Could not set locale to ''.
# (RolloutWorker pid=583835) Warning: Could not set locale to ''.
# (RolloutWorker pid=583836) Warning: Could not set locale to ''.
# (RolloutWorker pid=583834) Warning: Could not set locale to ''.
# (RolloutWorker pid=583837) ***Starting server on port 58915 ***
# (RolloutWorker pid=583835) ***Starting server on port 50655 ***
# (RolloutWorker pid=583836) ***Starting server on port 57117 ***
# (RolloutWorker pid=583834) ***Starting server on port 34217 ***
# (RolloutWorker pid=583837) Loading net-file from 'map/3km_1week/osm.net.xml.gz' ...
# (RolloutWorker pid=583836) Loading net-file from 'map/3km_1week/osm.net.xml.gz' ...
# (RolloutWorker pid=583834) Loading net-file from 'map/3km_1week/osm.net.xml.gz' ...
# (RolloutWorker pid=583835) Loading net-file from 'map/3km_1week/osm.net.xml.gz' ...
# (RolloutWorker pid=583835) done (594ms).
# (RolloutWorker pid=583836) done (618ms).
# (RolloutWorker pid=583837) done (750ms).
# (RolloutWorker pid=583835) Loading additional-files from 'map/3km_1week/osm.poly.xml.gz' ...
# (RolloutWorker pid=583836) Loading additional-files from 'map/3km_1week/osm.poly.xml.gz' ...
# (RolloutWorker pid=583834) done (642ms).
# (RolloutWorker pid=583834) Loading additional-files from 'map/3km_1week/osm.poly.xml.gz' ...
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 3 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 4 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 5 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 7 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 8 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 9 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 12 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 13 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 14 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 11 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 12 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 13 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 14 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 20 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 21 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 17 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 20 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 3 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 4 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 29 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 7 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 8 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'joinedS_cluster_246579426_249398921_cluster_246579458_246612186', linkIndex 9 has no controlling detector.
# (RolloutWorker pid=583835) Warning: At actuated tlLogic 'joinedS_cluster_246579426_249398921_cluster_246579458_246612186', linkIndex 11 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 3 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 4 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 5 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 7 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 8 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 9 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 12 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 13 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 14 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 11 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 12 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 13 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 14 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 20 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 21 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 17 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 20 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 3 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 4 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 29 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 7 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 8 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'joinedS_cluster_246579426_249398921_cluster_246579458_246612186', linkIndex 9 has no controlling detector.
# (RolloutWorker pid=583836) Warning: At actuated tlLogic 'joinedS_cluster_246579426_249398921_cluster_246579458_246612186', linkIndex 11 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 3 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 4 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 5 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 7 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 8 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 9 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 12 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 13 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 14 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 11 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 12 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 13 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 14 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 20 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 21 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 17 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 20 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 3 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 4 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 29 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 7 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 8 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'joinedS_cluster_246579426_249398921_cluster_246579458_246612186', linkIndex 9 has no controlling detector.
# (RolloutWorker pid=583834) Warning: At actuated tlLogic 'joinedS_cluster_246579426_249398921_cluster_246579458_246612186', linkIndex 11 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 3 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 4 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_1119642655_1362160642_1741494495_1795305239_#5more', linkIndex 5 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 7 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 8 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 9 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 12 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 13 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_237527821_237529307_5667042216_5667042243_#1more', linkIndex 14 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 11 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 12 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 13 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_239707201_243990817_4734428038_5014445995', linkIndex 14 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 20 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_246294522_246294523_246294567_4747947573', linkIndex 21 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 17 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'cluster_247184642_3734189424_5239934380_885593725', linkIndex 20 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 3 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 4 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'joinedS_cluster_1345078973_1345078978_cluster_1345078996_1345079014', linkIndex 29 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 7 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 8 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 18 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'joinedS_cluster_241926220_241926356_5137978697_6935401656_cluster_241926223_241926371', linkIndex 19 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'joinedS_cluster_246579426_249398921_cluster_246579458_246612186', linkIndex 9 has no controlling detector.
# (RolloutWorker pid=583837) Warning: At actuated tlLogic 'joinedS_cluster_246579426_249398921_cluster_246579458_246612186', linkIndex 11 has no controlling detector.
# (RolloutWorker pid=583837) Loading additional-files from 'map/3km_1week/osm.poly.xml.gz' ...
# (RolloutWorker pid=583835) done (357ms).
# (RolloutWorker pid=583835) Loading additional-files from 'map/3km_1week/factory.prk.xml' ... done (1ms).
# (RolloutWorker pid=583836) done (387ms).
# (RolloutWorker pid=583836) Loading additional-files from 'map/3km_1week/factory.prk.xml' ... done (1ms).
# (RolloutWorker pid=583834) done (344ms).
# (RolloutWorker pid=583834) Loading additional-files from 'map/3km_1week/factory.prk.xml' ... done (1ms).
# (RolloutWorker pid=583837) done (367ms).
# (RolloutWorker pid=583837) Loading additional-files from 'map/3km_1week/factory.prk.xml' ... done (1ms).
# (RolloutWorker pid=583836) Loading done.
# (RolloutWorker pid=583836) Simulation version 1.15.0 started with time: 0.00.
# (RolloutWorker pid=583834) Loading done.
# (RolloutWorker pid=583835) Loading done.
# (RolloutWorker pid=583835) Simulation version 1.15.0 started with time: 0.00.
# (RolloutWorker pid=583835) [loading] lorry_0 start loading P1 at:Factory0
# (RolloutWorker pid=583836) [loading] lorry_0 start loading P1 at:Factory0
# (RolloutWorker pid=583834) Simulation version 1.15.0 started with time: 0.00.
# (RolloutWorker pid=583834) [loading] lorry_0 start loading P1 at:Factory0
# (RolloutWorker pid=583837) Loading done.
# (RolloutWorker pid=583837) Simulation version 1.15.0 started with time: 0.00.
# (RolloutWorker pid=583837) [loading] lorry_0 start loading P1 at:Factory0
# (RolloutWorker pid=583835) [loading] lorry_4 start loading P1 at:Factory0
# (RolloutWorker pid=583836) [loading] lorry_4 start loading P1 at:Factory0
# (RolloutWorker pid=583834) [loading] lorry_4 start loading P1 at:Factory0
# (RolloutWorker pid=583837) [loading] lorry_4 start loading P1 at:Factory0
# (RolloutWorker pid=583836) [loading] lorry_7 start loading P1 at:Factory0
# (RolloutWorker pid=583835) [loading] lorry_7 start loading P1 at:Factory0
# (RolloutWorker pid=583834) [loading] lorry_7 start loading P1 at:Factory0
# (RolloutWorker pid=583837) [loading] lorry_7 start loading P1 at:Factory0
# (RolloutWorker pid=583836) [loading] lorry_8 start loading P1 at:Factory0
# (RolloutWorker pid=583835) [loading] lorry_8 start loading P1 at:Factory0
# (RolloutWorker pid=583834) [loading] lorry_8 start loading P1 at:Factory0
# (RolloutWorker pid=583837) [loading] lorry_8 start loading P1 at:Factory0
# (RolloutWorker pid=583835) [loading] lorry_9 start loading P1 at:Factory0
# (RolloutWorker pid=583836) [loading] lorry_9 start loading P1 at:Factory0
# (RolloutWorker pid=583834) [loading] lorry_9 start loading P1 at:Factory0
# (RolloutWorker pid=583837) [loading] lorry_9 start loading P1 at:Factory0
# (RolloutWorker pid=583835) [loading] lorry_10 start loading P1 at:Factory0
# (RolloutWorker pid=583836) [loading] lorry_10 start loading P1 at:Factory0
# (RolloutWorker pid=583834) [loading] lorry_10 start loading P1 at:Factory0
# (RolloutWorker pid=583837) [loading] lorry_10 start loading P1 at:Factory0
# (RolloutWorker pid=583835) [loading] lorry_11 start loading P1 at:Factory0
# (RolloutWorker pid=583836) [loading] lorry_11 start loading P1 at:Factory0
# (RolloutWorker pid=583834) [loading] lorry_11 start loading P1 at:Factory0
# (RolloutWorker pid=583837) [loading] lorry_11 start loading P1 at:Factory0
# (RolloutWorker pid=583835) [MDP state] lorry_1 state: 0, time:300.0
# (RolloutWorker pid=583835) [MDP state] lorry_2 state: 0, time:300.0
# (RolloutWorker pid=583835) [MDP state] lorry_3 state: 0, time:300.0
# (RolloutWorker pid=583835) [MDP state] lorry_5 state: 0, time:300.0
# (RolloutWorker pid=583835) [MDP state] lorry_6 state: 0, time:300.0
# (RolloutWorker pid=583836) [MDP state] lorry_1 state: 0, time:300.0
# (RolloutWorker pid=583836) [MDP state] lorry_2 state: 0, time:300.0
# (RolloutWorker pid=583836) [MDP state] lorry_3 state: 0, time:300.0
# (RolloutWorker pid=583836) [MDP state] lorry_5 state: 0, time:300.0
# (RolloutWorker pid=583836) [MDP state] lorry_6 state: 0, time:300.0
# (RolloutWorker pid=583835) [MDP state] lorry_0 state: 0, time:310.0
# (RolloutWorker pid=583835) [MDP state] lorry_4 state: 0, time:310.0
# (RolloutWorker pid=583835) [MDP state] lorry_7 state: 0, time:311.0
# (RolloutWorker pid=583834) [MDP state] lorry_1 state: 0, time:300.0
# (RolloutWorker pid=583834) [MDP state] lorry_2 state: 0, time:300.0
# (RolloutWorker pid=583834) [MDP state] lorry_3 state: 0, time:300.0
# (RolloutWorker pid=583834) [MDP state] lorry_5 state: 0, time:300.0
# (RolloutWorker pid=583834) [MDP state] lorry_6 state: 0, time:300.0
# (RolloutWorker pid=583837) [MDP state] lorry_1 state: 0, time:300.0
# (RolloutWorker pid=583837) [MDP state] lorry_2 state: 0, time:300.0
# (RolloutWorker pid=583837) [MDP state] lorry_3 state: 0, time:300.0
# (RolloutWorker pid=583837) [MDP state] lorry_5 state: 0, time:300.0
# (RolloutWorker pid=583837) [MDP state] lorry_6 state: 0, time:300.0
# (RolloutWorker pid=583835) [MDP state] lorry_8 state: 0, time:317.0
# (RolloutWorker pid=583836) [MDP state] lorry_0 state: 0, time:310.0
# (RolloutWorker pid=583836) [MDP state] lorry_4 state: 0, time:310.0
# (RolloutWorker pid=583836) [MDP state] lorry_7 state: 0, time:311.0
# (RolloutWorker pid=583834) [MDP state] lorry_0 state: 0, time:310.0
# (RolloutWorker pid=583834) [MDP state] lorry_4 state: 0, time:310.0
# (RolloutWorker pid=583834) [MDP state] lorry_7 state: 0, time:311.0
# (RolloutWorker pid=583837) [MDP state] lorry_0 state: 0, time:310.0
# (RolloutWorker pid=583837) [MDP state] lorry_4 state: 0, time:310.0
# (RolloutWorker pid=583835) [MDP state] lorry_9 state: 0, time:322.0
# (RolloutWorker pid=583835) [MDP state] lorry_10 state: 0, time:322.0
# (RolloutWorker pid=583836) [MDP state] lorry_8 state: 0, time:317.0
# (RolloutWorker pid=583834) [MDP state] lorry_8 state: 0, time:317.0
# (RolloutWorker pid=583837) [MDP state] lorry_7 state: 0, time:311.0
# (RolloutWorker pid=583836) [MDP state] lorry_9 state: 0, time:322.0
# (RolloutWorker pid=583836) [MDP state] lorry_10 state: 0, time:322.0
# (RolloutWorker pid=583834) [MDP state] lorry_9 state: 0, time:322.0
# (RolloutWorker pid=583834) [MDP state] lorry_10 state: 0, time:322.0
# (RolloutWorker pid=583837) [MDP state] lorry_8 state: 0, time:317.0
# (RolloutWorker pid=583837) [MDP state] lorry_9 state: 0, time:322.0
# (RolloutWorker pid=583837) [MDP state] lorry_10 state: 0, time:322.0
# (RolloutWorker pid=583835) [MDP state] lorry_11 state: 0, time:331.0
# (RolloutWorker pid=583836) [MDP state] lorry_11 state: 0, time:331.0
# (RolloutWorker pid=583834) [MDP state] lorry_11 state: 0, time:331.0
# (RolloutWorker pid=583837) [MDP state] lorry_11 state: 0, time:331.0
# (RolloutWorker pid=583835) [unloading] lorry_0 start unloading P1 at:Factory1
# (RolloutWorker pid=583836) [unloading] lorry_0 start unloading P1 at:Factory1
# (RolloutWorker pid=583834) [unloading] lorry_0 start unloading P1 at:Factory1
# (RolloutWorker pid=583837) [unloading] lorry_0 start unloading P1 at:Factory1
# (RolloutWorker pid=583835) [loading] lorry_0 start loading P2 at:Factory1
# (RolloutWorker pid=583836) [loading] lorry_0 start loading P2 at:Factory1
# (RolloutWorker pid=583834) [loading] lorry_0 start loading P2 at:Factory1
# (RolloutWorker pid=583837) [loading] lorry_0 start loading P2 at:Factory1
# (RolloutWorker pid=583835) [unloading] lorry_10 start unloading P1 at:Factory1
# (RolloutWorker pid=583836) [unloading] lorry_10 start unloading P1 at:Factory1
# (RolloutWorker pid=583835) [loading] lorry_3 start loading P2 at:Factory1
# (RolloutWorker pid=583836) [loading] lorry_3 start loading P2 at:Factory1
# (RolloutWorker pid=583834) [unloading] lorry_10 start unloading P1 at:Factory1
# (RolloutWorker pid=583837) [unloading] lorry_10 start unloading P1 at:Factory1
# (RolloutWorker pid=583835) [loading] lorry_6 start loading P2 at:Factory1
# (RolloutWorker pid=583834) [loading] lorry_3 start loading P2 at:Factory1
# (RolloutWorker pid=583835) [unloading] lorry_11 start unloading P1 at:Factory1
# (RolloutWorker pid=583837) [loading] lorry_3 start loading P2 at:Factory1
# (RolloutWorker pid=583835) [unloading] lorry_4 start unloading P1 at:Factory1
# (RolloutWorker pid=583836) [loading] lorry_6 start loading P2 at:Factory1
# (RolloutWorker pid=583836) [unloading] lorry_11 start unloading P1 at:Factory1
# (RolloutWorker pid=583834) [loading] lorry_6 start loading P2 at:Factory1
# (RolloutWorker pid=583835) [loading] lorry_2 start loading P2 at:Factory1
# (RolloutWorker pid=583836) [unloading] lorry_4 start unloading P1 at:Factory1
# (RolloutWorker pid=583834) [unloading] lorry_11 start unloading P1 at:Factory1
# (RolloutWorker pid=583834) [unloading] lorry_4 start unloading P1 at:Factory1
# (RolloutWorker pid=583837) [loading] lorry_6 start loading P2 at:Factory1
# (RolloutWorker pid=583837) [unloading] lorry_11 start unloading P1 at:Factory1
# (RolloutWorker pid=583836) [loading] lorry_2 start loading P2 at:Factory1
# (RolloutWorker pid=583834) [loading] lorry_2 start loading P2 at:Factory1
# (RolloutWorker pid=583837) [unloading] lorry_4 start unloading P1 at:Factory1
# (RolloutWorker pid=583835) [unloading] lorry_7 start unloading P1 at:Factory1
# (RolloutWorker pid=583835) [loading] lorry_4 start loading P2 at:Factory1
# (RolloutWorker pid=583836) [unloading] lorry_7 start unloading P1 at:Factory1
# (RolloutWorker pid=583837) [loading] lorry_2 start loading P2 at:Factory1
# (RolloutWorker pid=583835) [unloading] lorry_9 start unloading P1 at:Factory1
# (RolloutWorker pid=583835) [loading] lorry_11 start loading P12 at:Factory1
# (RolloutWorker pid=583836) [loading] lorry_4 start loading P2 at:Factory1
# (RolloutWorker pid=583834) [unloading] lorry_7 start unloading P1 at:Factory1
# (RolloutWorker pid=583834) [loading] lorry_4 start loading P2 at:Factory1
# (RolloutWorker pid=583837) [unloading] lorry_7 start unloading P1 at:Factory1
# (RolloutWorker pid=583835) [loading] lorry_1 start loading P2 at:Factory1
# (RolloutWorker pid=583836) [unloading] lorry_9 start unloading P1 at:Factory1
# (RolloutWorker pid=583836) [loading] lorry_11 start loading P12 at:Factory1
# (RolloutWorker pid=583834) [unloading] lorry_9 start unloading P1 at:Factory1
# (RolloutWorker pid=583834) [loading] lorry_11 start loading P12 at:Factory1
# (RolloutWorker pid=583837) [loading] lorry_4 start loading P2 at:Factory1
# (RolloutWorker pid=583835) [unloading] lorry_8 start unloading P1 at:Factory1
# (RolloutWorker pid=583835) [loading] lorry_9 start loading P12 at:Factory1
# (RolloutWorker pid=583836) [loading] lorry_1 start loading P2 at:Factory1
# (RolloutWorker pid=583836) [unloading] lorry_8 start unloading P1 at:Factory1
# (RolloutWorker pid=583834) [loading] lorry_1 start loading P2 at:Factory1
# (RolloutWorker pid=583836) [loading] lorry_9 start loading P12 at:Factory1
# (RolloutWorker pid=583837) [unloading] lorry_9 start unloading P1 at:Factory1
# (RolloutWorker pid=583837) [loading] lorry_11 start loading P12 at:Factory1
# (RolloutWorker pid=583834) [unloading] lorry_8 start unloading P1 at:Factory1
# (RolloutWorker pid=583834) [loading] lorry_9 start loading P12 at:Factory1
# (RolloutWorker pid=583837) [loading] lorry_1 start loading P2 at:Factory1
# (RolloutWorker pid=583837) [unloading] lorry_8 start unloading P1 at:Factory1
# (RolloutWorker pid=583835) [loading] lorry_8 start loading P2 at:Factory1
# (RolloutWorker pid=583836) [loading] lorry_8 start loading P2 at:Factory1
# (RolloutWorker pid=583837) [loading] lorry_9 start loading P12 at:Factory1
# (RolloutWorker pid=583835) [loading] lorry_5 start loading P12 at:Factory1
# (RolloutWorker pid=583834) [loading] lorry_8 start loading P2 at:Factory1
# (RolloutWorker pid=583837) [loading] lorry_8 start loading P2 at:Factory1
# (RolloutWorker pid=583836) [loading] lorry_5 start loading P12 at:Factory1
# (RolloutWorker pid=583834) [loading] lorry_5 start loading P12 at:Factory1
# (RolloutWorker pid=583837) [loading] lorry_5 start loading P12 at:Factory1
# (RolloutWorker pid=583836) [maintenance] lorry_0 go to state 4
# (RolloutWorker pid=583837) [maintenance] lorry_0 go to state 4
# (RolloutWorker pid=583835) [MDP state] lorry_2 state: 0, time:611.0
# (RolloutWorker pid=583835) [MDP state] lorry_3 state: 0, time:611.0
# (RolloutWorker pid=583835) [MDP state] lorry_5 state: 0, time:611.0
# (RolloutWorker pid=583835) [MDP state] lorry_1 state: 0, time:615.0
# (RolloutWorker pid=583835) [MDP state] lorry_6 state: 0, time:615.0
# (RolloutWorker pid=583836) [MDP state] lorry_2 state: 0, time:611.0
# (RolloutWorker pid=583836) [MDP state] lorry_3 state: 0, time:611.0
# (RolloutWorker pid=583836) [MDP state] lorry_5 state: 0, time:611.0
# (RolloutWorker pid=583836) Error: Answered with error to command 0xc4: stop for vehicle 'lorry_0' on lane '649150489_0' is too close to brake.
# (RolloutWorker pid=583836) Error: Answered with error to command 0xc4: stop for vehicle 'lorry_0' on lane '632227700_0' has an invalid position.
# (RolloutWorker pid=583837) Error: Answered with error to command 0xc4: stop for vehicle 'lorry_0' on lane '649150489_0' is too close to brake.
# (RolloutWorker pid=583837) Error: Answered with error to command 0xc4: stop for vehicle 'lorry_0' on lane '632227700_0' has an invalid position.
# (RolloutWorker pid=583836) [MDP state] lorry_1 state: 0, time:615.0
# (RolloutWorker pid=583836) [MDP state] lorry_6 state: 1, time:615.0
# (RolloutWorker pid=583834) [MDP state] lorry_2 state: 0, time:611.0
# (RolloutWorker pid=583834) [MDP state] lorry_3 state: 0, time:611.0
# (RolloutWorker pid=583834) [MDP state] lorry_5 state: 0, time:611.0
# ...
# (RolloutWorker pid=590133) [MDP state] lorry_1 state: 0, time:2015.0
# (RolloutWorker pid=590130) [MDP state] lorry_1 state: 0, time:2015.0
# (RolloutWorker pid=590129) [MDP state] lorry_7 state: 0, time:2019.0
# (RolloutWorker pid=590129) [MDP state] lorry_1 state: 0, time:2030.0
# (RolloutWorker pid=590129) [MDP state] lorry_8 state: 0, time:2031.0
# (RolloutWorker pid=590133) [MDP state] lorry_8 state: 0, time:2036.0
# (RolloutWorker pid=590130) [MDP state] lorry_8 state: 0, time:2036.0
# (RolloutWorker pid=590134) [unloading] lorry_4 start unloading P23 at:Factory3
# (RolloutWorker pid=590129) [loading] lorry_2 start loading P1 at:Factory0
# (RolloutWorker pid=590133) [loading] lorry_11 start loading P1 at:Factory0
# (RolloutWorker pid=590130) [loading] lorry_11 start loading P1 at:Factory0
# (RolloutWorker pid=590134) [MDP state] lorry_10 state: 0, time:2020.0
# (RolloutWorker pid=590134) [loading] lorry_8 start loading P1 at:Factory0
# (RolloutWorker pid=590129) [loading] lorry_9 start loading P1 at:Factory0
# (RolloutWorker pid=590133) [loading] lorry_9 start loading P1 at:Factory0
# (RolloutWorker pid=590130) [loading] lorry_9 start loading P1 at:Factory0
# (RolloutWorker pid=590134) [MDP state] lorry_1 state: 0, time:2033.0
# (RolloutWorker pid=590134) [loading] lorry_11 start loading P1 at:Factory0
# (RolloutWorker pid=590129) [loading] lorry_11 start loading P1 at:Factory0
# (RolloutWorker pid=590134) [loading] lorry_6 start loading P1 at:Factory0
# (RolloutWorker pid=590129) [loading] lorry_8 start loading P1 at:Factory0
# (RolloutWorker pid=590130) [MDP state] lorry_4 state: 0, time:2077.0
# (RolloutWorker pid=590129) [MDP state] lorry_9 state: 1, time:2071.0
# (RolloutWorker pid=590133) [MDP state] lorry_4 state: 0, time:2077.0
# (RolloutWorker pid=590130) [MDP state] lorry_9 state: 0, time:2082.0
# (RolloutWorker pid=590133) [MDP state] lorry_9 state: 0, time:2082.0
# (RolloutWorker pid=590133) [loading] lorry_8 start loading P1 at:Factory0
# (RolloutWorker pid=590130) [loading] lorry_8 start loading P1 at:Factory0
# (RolloutWorker pid=590134) [MDP state] lorry_6 state: 0, time:2073.0
# (RolloutWorker pid=590134) [MDP state] lorry_8 state: 1, time:2074.0
# (RolloutWorker pid=590129) [MDP state] lorry_11 state: 0, time:2089.0
# (RolloutWorker pid=590133) [MDP state] lorry_11 state: 0, time:2094.0
# (RolloutWorker pid=590130) [MDP state] lorry_11 state: 0, time:2094.0
# (RolloutWorker pid=590129) [MDP state] lorry_2 state: 0, time:2094.0
# (RolloutWorker pid=590134) [loading] lorry_5 start loading P1 at:Factory0
# (RolloutWorker pid=590129) [unloading] lorry_6 start unloading P23 at:Factory3
# (RolloutWorker pid=590134) [loading] lorry_10 start loading P2 at:Factory1
# (RolloutWorker pid=590129) [unloading] lorry_7 start unloading P23 at:Factory3
# (RolloutWorker pid=590133) [MDP state] lorry_7 state: 0, time:2120.0
# (RolloutWorker pid=590130) [MDP state] lorry_7 state: 0, time:2120.0
# (RolloutWorker pid=590134) [MDP state] lorry_11 state: 0, time:2103.0
# 2022-12-06 10:41:11,770	WARNING tune.py:705 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# (RolloutWorker pid=590134) [unloading] lorry_9 start unloading P23 at:Factory3
# (RolloutWorker pid=590133) [MDP state] lorry_3 state: 0, time:2167.0
# (RolloutWorker pid=590130) [MDP state] lorry_3 state: 0, time:2167.0
# (RolloutWorker pid=590134) [loading] lorry_7 start loading P2 at:Factory1
# (RolloutWorker pid=590129) [loading] lorry_4 start loading P2 at:Factory1
# (RolloutWorker pid=590133) [MDP state] lorry_2 state: 0, time:2179.0
# (RolloutWorker pid=590130) [MDP state] lorry_2 state: 1, time:2179.0
# (RolloutWorker pid=590129) [unloading] lorry_3 start unloading P23 at:Factory3
# (RolloutWorker pid=590129) [MDP state] lorry_4 state: 0, time:2185.0
# (RolloutWorker pid=590134) [MDP state] lorry_2 state: 0, time:2172.0
# (RolloutWorker pid=590133) [MDP state] lorry_10 state: 0, time:2198.0
# (RolloutWorker pid=590130) [MDP state] lorry_10 state: 0, time:2198.0
# (RolloutWorker pid=590134) [MDP state] lorry_3 state: 0, time:2175.0
# (RolloutWorker pid=590134) [MDP state] lorry_7 state: 1, time:2178.0
# (RolloutWorker pid=590134) [unloading] lorry_3 start unloading P23 at:Factory3
# (RolloutWorker pid=590134) [MDP state] lorry_4 state: 0, time:2191.0
# (RolloutWorker pid=590133) [MDP state] lorry_5 state: 0, time:2227.0
# (RolloutWorker pid=590130) [MDP state] lorry_5 state: 0, time:2227.0
# (RolloutWorker pid=590133) [unloading] lorry_2 start unloading P23 at:Factory3
# (RolloutWorker pid=590130) [unloading] lorry_2 start unloading P23 at:Factory3
# (RolloutWorker pid=590133) [unloading] lorry_10 start unloading P12 at:Factory2
# (RolloutWorker pid=590133) [unloading] lorry_1 start unloading P23 at:Factory3
# (RolloutWorker pid=590130) [unloading] lorry_10 start unloading P12 at:Factory2
# (RolloutWorker pid=590130) [unloading] lorry_1 start unloading P23 at:Factory3
# (RolloutWorker pid=590134) [loading] lorry_2 start loading P2 at:Factory1
# (RolloutWorker pid=590133) [loading] lorry_10 start loading P23 at:Factory2
# (RolloutWorker pid=590130) [loading] lorry_10 start loading P23 at:Factory2
# (RolloutWorker pid=590129) [MDP state] lorry_10 state: 0, time:2263.0
# (RolloutWorker pid=590129) [unloading] lorry_5 start unloading P2 at:Factory2
# (RolloutWorker pid=590133) [MDP state] lorry_6 state: 0, time:2278.0
# (RolloutWorker pid=590130) [MDP state] lorry_6 state: 0, time:2278.0
# (RolloutWorker pid=590129) [loading] lorry_5 start loading P23 at:Factory2
# (RolloutWorker pid=590129) [unloading] lorry_10 start unloading P2 at:Factory2
# (RolloutWorker pid=590129) [MDP state] lorry_3 state: 0, time:2312.0
# (RolloutWorker pid=590129) [loading] lorry_10 start loading P23 at:Factory2
# (RolloutWorker pid=590129) Error: tcpip::Socket::recvAndCheck @ recv: peer shutdown
# (RolloutWorker pid=590129) Quitting (on error).
# (RolloutWorker pid=590134) Error: tcpip::Socket::recvAndCheck @ recv: peer shutdown
# (RolloutWorker pid=590134) Quitting (on error).
# (RolloutWorker pid=590133) Error: tcpip::Socket::recvAndCheck @ recv: peer shutdown
# (RolloutWorker pid=590133) Quitting (on error).
# (RolloutWorker pid=590130) Error: tcpip::Socket::recvAndCheck @ recv: peer shutdown
# (RolloutWorker pid=590130) Quitting (on error).
# 2022-12-06 10:41:14,991	ERROR tune.py:773 -- Trials did not complete: [PPO_sumoEnv_37907_00000]
# 2022-12-06 10:41:14,992	INFO tune.py:777 -- Total run time: 530.94 seconds (530.70 seconds for the tuning loop).
# 2022-12-06 10:41:14,993	WARNING tune.py:783 -- Experiment has been interrupted, but the most recent state was saved. You can continue running this experiment by passing `resume=True` to `tune.run()`
# (RolloutWorker pid=590134) [MDP state] lorry_5 state: 0, time:2305.0
# (RolloutWorker pid=590134) DijkstraRouter answered 1560 queries and explored 379.69 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.70s answering queries (0.45ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 418 queries and explored 336.82 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.17s answering queries (0.40ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 119 queries and explored 356.76 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.05s answering queries (0.39ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 1 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 62 queries and explored 599.39 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.05s answering queries (0.85ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 50 queries and explored 724.88 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.04s answering queries (0.84ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 64 queries and explored 897.31 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.07s answering queries (1.11ms on average).
# (RolloutWorker pid=590134) DijkstraRouter answered 12 queries and explored 1137.67 edges on average.
# (RolloutWorker pid=590134) DijkstraRouter spent 0.02s answering queries (1.50ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 1573 queries and explored 381.54 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.67s answering queries (0.43ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 421 queries and explored 334.47 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.16s answering queries (0.38ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 120 queries and explored 366.22 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.05s answering queries (0.40ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 1 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 68 queries and explored 588.59 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.06s answering queries (0.90ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 48 queries and explored 718.08 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.04s answering queries (0.81ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 60 queries and explored 890.97 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.07s answering queries (1.17ms on average).
# (RolloutWorker pid=590129) DijkstraRouter answered 16 queries and explored 1052.50 edges on average.
# (RolloutWorker pid=590129) DijkstraRouter spent 0.02s answering queries (1.38ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 1578 queries and explored 378.29 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.64s answering queries (0.41ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 422 queries and explored 344.34 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.17s answering queries (0.40ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 120 queries and explored 366.00 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.05s answering queries (0.43ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 1 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 66 queries and explored 584.76 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.05s answering queries (0.73ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 46 queries and explored 710.70 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.04s answering queries (0.80ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 72 queries and explored 940.50 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.09s answering queries (1.21ms on average).
# (RolloutWorker pid=590133) DijkstraRouter answered 12 queries and explored 1138.00 edges on average.
# (RolloutWorker pid=590133) DijkstraRouter spent 0.02s answering queries (1.42ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 1578 queries and explored 378.29 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.66s answering queries (0.42ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 422 queries and explored 344.34 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.17s answering queries (0.39ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 120 queries and explored 366.00 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.05s answering queries (0.41ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 2 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 1 queries and explored 1.00 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.00s answering queries (0.00ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 66 queries and explored 584.76 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.06s answering queries (0.89ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 46 queries and explored 710.70 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.04s answering queries (0.85ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 72 queries and explored 940.50 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.08s answering queries (1.17ms on average).
# (RolloutWorker pid=590130) DijkstraRouter answered 12 queries and explored 1138.00 edges on average.
# (RolloutWorker pid=590130) DijkstraRouter spent 0.02s answering queries (1.67ms on average).
